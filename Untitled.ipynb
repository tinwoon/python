# %% [markdown]
# ## [1번 문제]
#
# 클래스와 모듈의 공통점과 차이점에 대해 설명하시오.

# %% [markdown]
# 공통점: 이름공간을 제공한다
#
# 차이점: 클래스는 직접 공간을 작성하여 객체를 만들어 사용,
#         모듈은 파일상태로 공간을 작성하여 묶어 사용.

# %% [markdown]
# ## [2번 문제]
#
# 다형성에 대해 설명하고 다형성을 보여주는 자신만의 파이썬 코드 예제를 제시하시오.

# %%
class jiwonzzang:
    def calculate(a,b):
        return a+b

class jiwongood(jiwonzzang):
    def calculate(a,b):
        return a*b

class jiwonnice(jiwonzzang):
    def calculate(a,b):
        return a/b

jiwon=jiwongood
print(jiwon.calculate(2,3))
jiwon=jiwonnice
print(jiwon.calculate(2,3))
# Out:
# 6
# 0.6666666666666666

# %% [markdown]
# 다형성은 다른클라스들의 사례들이 같은 멤버함수 호출에 대해 각각 다르게 반응하도록 하는 기능으로서 장점으로는 적은 코딩으로 다양한 객체들에게 유사한 작업 수행, 프로그램 작성 코드 량이 줄어든다, 코드의 가독성을 높혀준다가 있다.

# %% [markdown]
# ## [3번 문제]
#
# 다음 각 요구사항 모두를 만족시키는 Counter 클래스를 코딩하시오 (정답을 각 요구사항별로 입력할 필요 없이 3번 문제에 대해 1개의 클래스 정의 코드를 제시하면 된다.)
#
#
# •요구사항 1. 생성자에 count 값과 step 값을 인자로 받을 수 있다.
# ◾count: Counter 인스턴스가 지니는 초기 정수 값
# ◾step: Counter 인스턴스의 count가 증가되는 증분 (defalt 값: 1)
#
#
# >>> c = Counter(10)
#  >>> d = Counter(10, 2)
#
#
#
# •요구사항 2. 다음과 같이 Counter의 인스턴스를 출력을 해주는 __str__() 메소드를 Counter 클래스 내에 구현하시오.
#
#
# >>> print(c)
#  [Count (step: 1)] 10
#  >>> print(d)
#  [Count (step: 2)] 10
#
#
#
# •요구사항 3. 다음과 같이 step에 주어진 증분만큼 count를 증가시키는 incr() 메소드를 Counter 클래스 내에 구현하시오.
#
#
# >>> c.incr()
#  >>> d.incr()
#  >>> print(c)
#  [Count (step: 1)] 11
#  >>> print(d)
#  [Count (step: 2)] 12
#
#
#
# •요구사항 4. Counter 클래스 내에 관련 메소드를 추가하여 인스턴스 객체를 직접 호출(call)할 수 있도록 하시오. 인스턴스 객체를 직접 호출했을 때에 내부적으로 incr() 메소드를 호출하는 방법으로 구현하시오.
#
#
# >>> c()
#  >>> d()
#  >>> print(c)
#  [Count (step: 1)] 12
#  >>> print(d)
#  [Count (step: 2)] 14
#
#
#
# •요구사항 5. 다음과 같은 두 개의 산술 연산 (+, -)이 수행될 수 있도록 Counter 클래스 내에 관련 메소드를 추가하시오.
#
#
# >>> c = c + 5
#  >>> d = d - 5
#  >>> print(c)
#  [Count (step: 1)] 17
#  >>> print(d)
#  [Count (step: 2)] 9
#
#
#
# •요구사항 6. 다음과 같은 관계연산 (>, <, ==)이 수행될 수 있도록 Counter 클래스 내에 관련 메소드를 추가하시오.
#
#
# >>> print(c) > 10
#  True
#  >>> print(d) > 10
#  False
#  >>> print(c) < 10
#  False
#  >>> print(d) < 10
#  True
#  >>> print(c) == 17
#  True
#  >>> print(d) != 9
#  False

# %%
class Counter:
    def __init__(self, cnt, stp=1): #생성자를 보내는 것
        self.count=cnt
        self.step=stp
    
    def __str__(self): #인스턴스 값들을 내보내는 것
        return '[Count(step:%s)] %s' %(self.step,self.count)
    
    def increase(self): #스텝 만큼 카운트 올리는 것
        self.count = self.count + self.step
        
    def __call__(self): #스텝카운트를 실행시키는것
        self.increase()
   
    def __add__(self,other): #증가하는 것
        return Counter(self.count+other,self.step)
    
    def __sub__(self, other): #빼는것
        return Counter(self.count- other, self.step)
    
    def __gt__(self,other):# 크기 비교해서
        return self.count>other
    
    def __lt__(self, other):# 크기비교
        return self.count<other
    
    def __eq__(self,other):#같은지 비교
        return self.count==other
    
    def __ne__(self,other):#다른지 비교
        return self.count!=other 
    
c= Counter(10)

d =Counter(10,2)

print(c)
print(d)

print()

c.increase()
d.increase()

print(c)
print(d)
print()

c()
d()
print(c)
print(d)
print()

c=c+5
d=d-5
print(c)
print(d)
print()

print(c>5)
print(d>5)
print (c<10)
print (d<10)
print (c==17)
print (d!=9)
# Out:
# [Count(step:1)] 10
# [Count(step:2)] 10
#
# [Count(step:1)] 11
# [Count(step:2)] 12
#
# [Count(step:1)] 12
# [Count(step:2)] 14
#
# [Count(step:1)] 17
# [Count(step:2)] 9
#
# True
# True
# False
# True
# True
# False

# %% [markdown]
# ## [4번 문제]
#
# 다음은 내장 자료형 list를 서브클래싱하여 만든 MySet 클래스 정의 내용이다. 다음 클래스 정의에서 __init__(), __str()__(), elimicate_duplicate()의 세 개의 메소드 코드 내용을 자신이 다른 사람에게 가르친다고 생각하며 설명해보시오.
# •MySet은 집합(Set) 자료형을 정의하려는 의도하에 만들어진 클래스이다.

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + ","
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print(s)
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print(t)
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %% [markdown]
# eliminate_duplicate(l)은 l에 있는 문자열중 중복되지 않도록 한 값들을 e에 넣고 그다음 l에 다시 l에 넣는 함수이다.
# __init__(self,l)함수는 l에 있는 함수를 eliminate_duplicate()함수를 통해 중복을 제거해준다.
# __str__(self)함수를 문자열을 {}모양으로 정렬해준다.

# %% [markdown]
# ## [5번 문제]
#
# 4번 문제에 정의된 MySet 클래스에 메소드를 추가하여 다음 각 요구사항 모두를 만족시키는 코딩을 제시하시오
# •정답을 각 요구사항별로 입력할 필요 없이 요구사항 3개 전체에 대해 1개의 MySet 클래스 정의 코드를 제시하고 주석등으로 해당 코드를 설명한다.
#
# •요구사항 1. | 연산으로 두 집합의 합집합을 반환한다.
#
#
# >>> u = s | t
#  >>> print(u)
#  MySet: {1, 2, 3, 4, 5, 6, 7, 8, 9}
#
#
#
# •요구사항 2. & 연산으로 두 집합의 교집합을 반환한다.
#
#
# >>> u = s & t
#  >>> print(u)
#  MySet: {2, 3}
#
#
#
# •요구사항 3. - 연산으로 두 집합의 차집합을 반환한다.
#
#
# >>> s = MySet([1, 2, 3])
#  >>> t = MySet([3, 4, 5])
#  >>> u = s - t
#  >>> print(u)
#  MySet: {1, 2}

# %%
class MySet_ver2(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet2.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySetver2: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    
    def __or__(self, other):#self의 값을 붙이고 끝나면 other값을 붙인후 정렬시킴
        temp=[]
        for e in self:
            temp.append(e)
        for h in other:
            temp.append(h)
        MySet2.eliminate_duplicate(temp)
        return MySet2(temp)
    
    def __and__(self, other):#값을 붙이는 set1버전을 실행
        return MySet2.set_ver1(self, other)

    def __sub__(self, other):# 값이 중복되지 않으면 붙이는 set2버전을 실행
        temp=[]
        for e in self:
            temp.append(e)
        temp2=MySet2.set_ver1(self, other)
        return MySet2.set_ver2(temp, temp2)
    
    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)
    @staticmethod
    def set_ver1(l,k):#값을 붙여놓는 set버전을 실행
        s=[]
        for e in l:
            if e in k:
                s.append(e)
        l[:]=[]
        for e in s:
            l.append(e)
        return l
    
    @staticmethod
    def set_ver2(t1,t2):#값이 중복되지 않으면 붙이는 set2버전을 실행
        s=[]
        for e in t1:
            if e not in t2:
                s.append(e)
        return MySet2(s)        
    
if __name__ == "__main__":
    s = MySet2([1, 2, 2, 3])
    print(s)
    t = MySet2([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print(t)
    
    u=s|t
    
    print(u)
    u=s&t
    
    print(u)
    
    s=MySet2([1,2,3])
    t=MySet2([3,4,5])
    u=s-t
    
    print(u)
# Out:
# MySet2: {1 ,2 ,3}
# MySet2: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}
# MySet2: {1 ,2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}
# MySet2: {2 ,3}
# MySet2: {1 ,2}

# %% [markdown]
# ## [6번 문제]
# 5번 문제에서 정의한 MySet 클래스에 대해 다음 예제를 수행하면 오류없이 올바르게 동작하는 것을 확인할 수 있다. 다음 예제 내에 있는 len(), bool() 내장함수와 in 키워드 사용 예제가 별다른 메소드 정의를 하지 않았는 데도 올바르게 수행되는 이유를 설명하시오.
# >>> s = MySet([1, 2, 3, 4, 5, 6])
# >>> print(len(s))
# > 6
# >>> print(bool(s))
# > True
# >>> print(2 in s)
# > True

# %%
class MySet_ver2(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet2.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySetver2: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    
    def __or__(self, other):#self의 값을 붙이고 끝나면 other값을 붙인후 정렬시킴
        temp=[]
        for e in self:
            temp.append(e)
        for h in other:
            temp.append(h)
        MySet2.eliminate_duplicate(temp)
        return MySet2(temp)
    
    def __and__(self, other):#값을 붙이는 set1버전을 실행
        return MySet2.set_ver1(self, other)

    def __sub__(self, other):# 값이 중복되지 않으면 붙이는 set2버전을 실행
        temp=[]
        for e in self:
            temp.append(e)
        temp2=MySet2.set_ver1(self, other)
        return MySet2.set_ver2(temp, temp2)
    
    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)
    @staticmethod
    def set_ver1(l,k):
        s=[]
        for e in l:
            if e in k:
                s.append(e)
        l[:]=[]
        for e in s:
            l.append(e)
        return l
    
    @staticmethod
    def set_ver2(t1,t2):
        s=[]
        for e in t1:
            if e not in t2:
                s.append(e)
        return MySet2(s)        
    
if __name__ == "__main__":
    s = MySet2([1,2,3,4,5,6])
    print(len(s))
    
    print(bool(s))
    
    print(2 in s)
# Out:
# 6
# True
# True

# %% [markdown]
# 이미 설정되어 있는 메소드를 출력하는데에는 이상없이 실행된다.
